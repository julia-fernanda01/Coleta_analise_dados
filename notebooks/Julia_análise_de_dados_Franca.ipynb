# %% [markdown]
# <a href="https://colab.research.google.com/github/julia-fernanda01/Coleta_analise_dados/blob/main/notebooks/Julia_an%C3%A1lise_de_dados_Franca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução

# %% [markdown]
# ## Importações de programas e bibliotecas
#
# - O código abaixa indica os programas e bibliotecas que serão utilizados nesse arquivo

# %%
import json
import os
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Interação com o Google Drive

# %%
caminho_padrao = "/content/gdrive/MyDrive" # comum a todos os usuários
caminho_especifico_dados = "/Notebooks/Dados/Franca/dom_franca_2024.json" # caminho especifico de cada usuário
caminho_completo = caminho_padrao + caminho_especifico_dados
caminho_completo
# Out:
# '/content/gdrive/MyDrive/Notebooks/Dados/Franca/dom_franca_2024.json'

# %% [markdown]
# # Análise exploratória inicial

# %% [markdown]
# ## Acessando as informações dos arquivos

# %%
dataset = pd.read_json(caminho_completo, orient="columns")
df_diarios = pd.json_normalize(dataset["_default"])
df_diarios
# Out:
#      tipo_dado                                    plataforma    origem  \
# 0    [Público]  https://www.imprensaoficialmunicipal.com.br/  [Franca]
# 1    [Público]  https://www.imprensaoficialmunicipal.com.br/  [Franca]
# 2    [Público]  https://www.imprensaoficialmunicipal.com.br/  [Franca]
# 3    [Público]  https://www.imprensaoficialmunicipal.com.br/  [Franca]
# 4    [Público]  https://www.imprensaoficialmunicipal.com.br/  [Franca]
# ..         ...                                           ...       ...
# 438    Público  https://www.imprensaoficialmunicipal.com.br/    Franca
# 439    Público  https://www.imprensaoficialmunicipal.com.br/    Franca
# 440    Público  https://www.imprensaoficialmunicipal.com.br/    Franca
# 441    Público  https://www.imprensaoficialmunicipal.com.br/    Franca
# 442    Público  https://www.imprensaoficialmunicipal.com.br/    Franca
#
#     origem_lower        nivel cod_identificacao    categoria          data  \
# ...

# %% [markdown]
# ## Pré-análise

# %%
df_diarios.shape
# Out:
# (443, 22)

# %%
df_diarios.columns
# Out:
# Index(['tipo_dado', 'plataforma', 'origem', 'origem_lower', 'nivel',
#        'cod_identificacao', 'categoria', 'data', 'num_ed', 'nome_arquivo',
#        'tamanho', 'link_pdf', 'conteudo', 'coleta_pdf', 'dir_bd', 'codigo_bd',
#        'dir_base', 'nome_arq_bd', 'dir_arquivo', 'dir_local', 'arq_local_pdf',
#        'nome_bd_json'],
#       dtype='object')

# %%
df_diarios[["data","categoria","num_ed","nome_arquivo","plataforma","nivel"]]
# Out:
#              data    categoria  num_ed  \
# 0    [04/01/2024]  [ordinario]  [2433]
# 1    [05/01/2024]  [ordinario]  [2434]
# 2    [06/01/2024]  [ordinario]  [2435]
# 3    [09/01/2024]  [ordinario]  [2436]
# 4    [10/01/2024]  [ordinario]  [2437]
# ..            ...          ...     ...
# 438    24/12/2024    ordinario    2674
# 439    25/12/2024    ordinario    2675
# 440    27/12/2024    ordinario    2676
# 441    28/12/2024    ordinario    2677
# 442    31/12/2024    ordinario    2678
#
#                                   nome_arquivo  \
# 0    [dom_franca_2024-01-04_ed-2433_ordinario]
# 1    [dom_franca_2024-01-05_ed-2434_ordinario]
# 2    [dom_franca_2024-01-06_ed-2435_ordinario]
# 3    [dom_franca_2024-01-09_ed-2436_ordinario]
# 4    [dom_franca_2024-01-10_ed-2437_ordinario]
# ..                                         ...
# 438    dom_franca_2024-12-24_ed-2674_ordinario
# 439    dom_franca_2024-12-25_ed-2675_ordinario
# 440    dom_franca_2024-12-27_ed-2676_ordinario
# ...
